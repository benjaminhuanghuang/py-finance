# %%
import pandas_datareader.data as web

# %%
df = web.get_data_yahoo("AAPL", start="2018-1-1")

# %% [markdown]
# 收盘价

# %%
p = df["Adj Close"]

# %%
p.plot()

# %% [markdown]
# 每天收益

# %%
r = p.diff()/p

# %%
r[-100:].plot()
